# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib as plt

# %%
df = pd.read_csv("SalesCRM-CRM.csv")
df.tail()
# Out:
#           ID Country Education First Contact Last Contact       Status Stage  \
# 11027  11789     USA       NaN    2022-04-21   2022-04-21  1st message   NaN
# 11028  11790     USA       NaN    2022-04-21   2022-04-21  1st message   NaN
# 11029  11791     USA       NaN    2022-04-21   2022-04-21  1st message   NaN
# 11030  11792     USA       NaN    2022-04-21   2022-04-21  1st message   NaN
# 11031  11793     USA       NaN    2022-04-21   2022-04-21  1st message   NaN
#
#       First Call Signed up for a demo Filled in customer survey  \
# 11027        NaN                  NaN                       NaN
# 11028        NaN                  NaN                       NaN
# 11029        NaN                  NaN                       NaN
# 11030        NaN                  NaN                       NaN
# 11031        NaN                  NaN                       NaN
#
#       Did sign up to the platform Account Manager assigned Subscribed
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11032 entries, 0 to 11031
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           11032 non-null  int64
#  1   Country                      10141 non-null  object
#  2   Education                    7429 non-null   object
#  3   First Contact                10317 non-null  object
#  4   Last Contact                 10722 non-null  object
#  5   Status                       10229 non-null  object
#  6   Stage                        944 non-null    object
#  7   First Call                   441 non-null    object
#  8   Signed up for a demo         283 non-null    object
#  9   Filled in customer survey    184 non-null    object
#  10  Did sign up to the platform  423 non-null    object
#  11  Account Manager assigned     71 non-null     object
#  12  Subscribed                   48 non-null     object
# ...

# %%
df['First Call'].value_counts()
# Out:
# 2021-01-05    7
# 2021-03-03    7
# 2022-02-12    6
# 2021-03-10    5
# 2021-02-26    5
#              ..
# 2021-05-18    1
# 2021-06-01    1
# 2021-05-13    1
# 2021-09-08    1
# 2022-04-09    1
# Name: First Call, Length: 242, dtype: int64

# %%
df['Country']
# Out:
# 0                         NaN
# 1                     Austria
# 2        United Arab Emirates
# 3                      France
# 4                         USA
#                  ...
# 11027                     USA
# 11028                     USA
# 11029                     USA
# 11030                     USA
# 11031                     USA
# Name: Country, Length: 11032, dtype: object

# %%
df['Country'].value_counts()
# Out:
# USA                         6604
# Canada                       817
# France                       336
# UK                           329
# Germany                      282
#                             ...
# uSA                            1
# Hong Kong                      1
# Singapore                      1
# Cameroon                       1
# Central African Republic       1
# Name: Country, Length: 103, dtype: int64

# %%
df.isnull().sum()
# Out:
# ID                                 0
# Country                          891
# Education                       3603
# First Contact                    715
# Last Contact                     310
# Status                           803
# Stage                          10088
# First Call                     10591
# Signed up for a demo           10749
# Filled in customer survey      10848
# Did sign up to the platform    10609
# Account Manager assigned       10961
# Subscribed                     10984
# dtype: int64

# %%
df.count()
# Out:
# ID                             11032
# Country                        10141
# Education                       7429
# First Contact                  10317
# Last Contact                   10722
# Status                         10229
# Stage                            944
# First Call                       441
# Signed up for a demo             283
# Filled in customer survey        184
# Did sign up to the platform      423
# Account Manager assigned          71
# Subscribed                        48
# dtype: int64

# %%
len(df.Country.unique())
# Out:
# 104

# %%
df.describe()
# Out:
#                  ID
# count  11032.000000
# mean    6019.066443
# std     3434.469290
# min        1.000000
# 25%     3123.750000
# 50%     6157.500000
# 75%     8989.250000
# max    11793.000000

# %%
pip install gym
# Out:
# ...
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# ...
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827648 sha256=9b1e8f6a2599a686969c618d044b04cda6bb92db8eafc9184da27689a21afb00
#   Stored in directory: c:\users\abedq\appdata\local\pip\cache\wheels\ae\5f\67\64914473eb34e9ba89dbc7eefe7e9be8f6673fbc6f0273b29f
# Successfully built gym
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import gym
from gym.spaces import Discrete, Box
from gym import Env
import random

# %%
class  salesAgent(Env):
    def __init__(self):
        #the code number of action we take either 1 or 2, or 3, or 0: maybe will have from around 10000 of number of countries
        self.action_space = Discrete(2) 
        #environmennt  array between 0 and number of countries
        self.observations_space = Box(low = np.array([0]), high = np.array([104]))
        #default for reward
        self.state = 50 + random.randint(-3,3)
    def step(self, reward):
                
        for i in range(len(df)):
            if df['Country'][i] == "USA" and df['Education'][i] == 'B1':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B3':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B4':
                reward = 120    
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B6':
                reward = 120
            elif df['Country'][i] == "USA" and  df['Education'][i] == 'B8':
                reward = 120
            elif df['Country'][i] == "USA" and  df['Education'][i] == 'B9':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B10':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B11':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B13':
                reward = 120
            elif df['Country'][i] == "USA" and  df['Education'][i] == 'B14':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B16':
                reward = 120
            elif df['Country'][i] == "USA" and  df['Education'][i] == 'B17':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B19':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B21':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B25':
                reward = 120
            elif df['Country'][i] == "USA" and  df['Education'][i] == 'B27':
                reward = 120
            elif df['Country'][i] == "USA" and  df['Education'][i] == 'B28':
                reward = 120
            elif df['Country'][i] == "USA" and df['Education'][i] == 'B29':
                reward = 120
            elif df['Country'][i] == "USA"and df['Education'][i] == 'B30':
                reward = 120
            elif df['Country'][i] == "France" and df['Education'][i] == 'B6':
                reward = 100
            elif df['Country'][i] == "France" and  df['Education'][i] == 'B8':
                reward = 100
            elif df['Country'][i] == "France"  and df['Education'][i] == 'B14':
                reward = 100
            elif df['Country'][i] == "France" and df['Education'][i] == 'B15':
                reward = 100
            elif df['Country'][i] == "France" and df['Education'][i] == 'B17':
                reward = 100
            elif df['Country'][i] == "France" and df['Education'][i] == 'B22': 
                reward = 100
            else:
                reward = -50
        
            info = {}
        return self.state, reward, done, info

            
    def reset(self):
        self.state = 50 + random.randint(-3,3)
        return self.state

# %%
actions = []
for i in range(len(df)):
    if df['Country'][i] == "USA" and df['Education'][i] == 'B1':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B3':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B4':
        actions.append(120)    
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B6':
        actions.append(120)
    elif df['Country'][i] == "USA" and  df['Education'][i] == 'B8':
        actions.append(120)        
    elif df['Country'][i] == "USA" and  df['Education'][i] == 'B9':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B10':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B11':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B13':
        actions.append(120)
    elif df['Country'][i] == "USA" and  df['Education'][i] == 'B14':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B16':
        actions.append(120)
    elif df['Country'][i] == "USA" and  df['Education'][i] == 'B17':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B19':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B21':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B25':
        actions.append(120)
    elif df['Country'][i] == "USA" and  df['Education'][i] == 'B27':
        actions.append(120)
    elif df['Country'][i] == "USA" and  df['Education'][i] == 'B28':
        actions.append(120)
    elif df['Country'][i] == "USA" and df['Education'][i] == 'B29':
        actions.append(120)
    elif df['Country'][i] == "USA"and df['Education'][i] == 'B30':
        actions.append(120)
    elif df['Country'][i] == "France" and df['Education'][i] == 'B6':
        actions.append(100)
    elif df['Country'][i] == "France" and  df['Education'][i] == 'B8':
        actions.append(100)
    elif df['Country'][i] == "France"  and df['Education'][i] == 'B14':
        actions.append(100)
    elif df['Country'][i] == "France" and df['Education'][i] == 'B15':
        actions.append(100)
    elif df['Country'][i] == "France" and df['Education'][i] == 'B17':
        actions.append(100)       
    elif df['Country'][i] == "France" and df['Education'][i] == 'B22': 
        actions.append(100)
    else:
        actions.append(-50)

# %%
df['actions'] = actions

# %%
df.actions.value_counts()
# Out:
# -50     5582
#  120    5209
#  100     241
# Name: actions, dtype: int64

# %%
env  = salesAgent()
# Out:
# C:\Users\abedq\anaconda3\lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
env.observations_space.sample()
# Out:
# array([54.64125], dtype=float32)

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.observations_space
# Out:
# Box(0.0, 104.0, (1,), float32)

# %%
episodes = 20 #20 shower episodes
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        print('action:{} n_state:{} reward:{} info:{}'.format(action, n_state, reward, info))
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:1 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# action:0 n_state:49 reward:-50 info:{}
# ...
